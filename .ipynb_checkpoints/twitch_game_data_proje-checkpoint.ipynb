# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn as sl
from sklearn.model_selection import train_test_split
from sklearn import linear_model
pd.options.mode.chained_assignment = None
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn as sl
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('Twitch_game_data.csv')

# %%
df.head(6)
# Out:
#    Rank                              Game  Month  Year  Hours_watched  \
# 0     1                 League of Legends      1  2016       94377226
# 1     2  Counter-Strike: Global Offensive      1  2016       47832863
# 2     3                            Dota 2      1  2016       45185893
# 3     4                       Hearthstone      1  2016       39936159
# 4     5       Call of Duty: Black Ops III      1  2016       16153057
# 5     6                         Minecraft      1  2016       10231056
#
#   Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0  1362044 hours        530270           2903     129172       127021
# 1   830105 hours        372654           2197     120849        64378
# 2   433397 hours        315083           1100      44074        60815
# 3   235903 hours        131357            517      36170        53749
# 4  1151578 hours         71639           3620     214054        21740
# 5   490002 hours         64432           1538      88820        13769
#
#    Avg_channels  Avg_viewer_ratio
# 0          1833             69.29
# 1          1117             57.62
# 2           583            104.26
# 3           317            169.29
# 4          1549             14.03
# 5           659             20.88

# %%
df.shape
# Out:
# (14200, 12)

# %%
df.dtypes
# Out:
# Rank                  int64
# Game                 object
# Month                 int64
# Year                  int64
# Hours_watched         int64
# Hours_Streamed       object
# Peak_viewers          int64
# Peak_channels         int64
# Streamers             int64
# Avg_viewers           int64
# Avg_channels          int64
# Avg_viewer_ratio    float64
# dtype: object

# %%
i=0
for item in df["Hours_Streamed"]:
    df["Hours_Streamed"].iloc[i] = np.int64(df["Hours_Streamed"].iloc[i][:-6])
    i+=1

# %%
df.mean()
# Out:
# Rank                1.005000e+02
# Month               6.422535e+00
# Year                2.018465e+03
# Hours_watched       4.730352e+06
# Hours_Streamed      1.556238e+05
# Peak_viewers        5.448747e+04
# Peak_channels       5.772570e+02
# Streamers           1.711976e+04
# Avg_viewers         6.485326e+03
# Avg_channels        2.129009e+02
# Avg_viewer_ratio    8.229296e+01
# dtype: float64

# %%
df.tail(5)
# Out:
#        Rank                   Game  Month  Year  Hours_watched Hours_Streamed  \
# 14195   196            War Thunder     11  2021         645300          71128
# 14196   197                  Dofus     11  2021         645248          20979
# 14197   198  Monster Hunter: World     11  2021         635375          69110
# 14198   199  Gas Station Simulator     11  2021         617396           8015
# 14199   200          Knight Online     11  2021         607581          23773
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 14195          6286            215       6374          897            98
# 14196          6319             71       1273          897            29
# 14197          5487            169       6686          883            96
# 14198         26865             38       1716          858            11
# 14199          3361             89       1152          845            33
#
#        Avg_viewer_ratio
# 14195              9.07
# 14196             30.76
# 14197              9.19
# 14198             77.03
# 14199             25.56

# %%
df.shape
# Out:
# (14200, 12)

# %%
df.isnull().sum()
# Out:
# Rank                0
# Game                1
# Month               0
# Year                0
# Hours_watched       0
# Hours_Streamed      0
# Peak_viewers        0
# Peak_channels       0
# Streamers           0
# Avg_viewers         0
# Avg_channels        0
# Avg_viewer_ratio    0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Rank                0
# Game                0
# Month               0
# Year                0
# Hours_watched       0
# Hours_Streamed      0
# Peak_viewers        0
# Peak_channels       0
# Streamers           0
# Avg_viewers         0
# Avg_channels        0
# Avg_viewer_ratio    0
# dtype: int64

# %%
df.describe().T
# Out:
#                     count          mean           std       min       25%  \
# Rank              14199.0  1.004957e+02  5.773606e+01      1.00      50.5
# Month             14199.0  6.422847e+00  3.413607e+00      1.00       3.0
# Year              14199.0  2.018465e+03  1.693772e+00   2016.00    2017.0
# Hours_watched     14199.0  4.730663e+06  1.653198e+07  89811.00  363514.5
# Peak_viewers      14199.0  5.448913e+04  1.317253e+05    441.00    8272.5
# Peak_channels     14199.0  5.768889e+02  2.631148e+03      1.00      51.0
# Streamers         14199.0  1.711943e+04  5.446563e+04      0.00    1461.0
# Avg_viewers       14199.0  6.485750e+03  2.267055e+04    120.00     498.0
# Avg_channels      14199.0  2.129079e+02  7.426681e+02      0.00      16.0
# Avg_viewer_ratio  14199.0  8.229846e+01  3.713222e+02      1.98      16.1
#
#                         50%         75%           max
# Rank                 100.00      150.00  2.000000e+02
# Month                  6.00        9.00  1.200000e+01
# Year                2018.00     2020.00  2.021000e+03
# Hours_watched     809434.00  2268004.50  3.445520e+08
# Peak_viewers       19950.00    45444.00  3.123208e+06
# Peak_channels        121.00      315.00  1.298600e+05
# Streamers           4088.00    10651.00  1.013029e+06
# Avg_viewers         1110.00     3104.50  4.792090e+05
# Avg_channels          42.00      120.00  1.378900e+04
# Avg_viewer_ratio      29.15       57.82  1.360187e+04

# %%
pd.set_option('float_format', '{:f}'.format)

# %%
df.describe()
# Out:
#               Rank        Month         Year    Hours_watched   Peak_viewers  \
# count 14199.000000 14199.000000 14199.000000     14199.000000   14199.000000
# mean    100.495669     6.422847  2018.464751   4730663.153955   54489.129516
# std      57.736064     3.413607     1.693772  16531982.222792  131725.254457
# min       1.000000     1.000000  2016.000000     89811.000000     441.000000
# 25%      50.500000     3.000000  2017.000000    363514.500000    8272.500000
# 50%     100.000000     6.000000  2018.000000    809434.000000   19950.000000
# 75%     150.000000     9.000000  2020.000000   2268004.500000   45444.000000
# max     200.000000    12.000000  2021.000000 344551979.000000 3123208.000000
#
#        Peak_channels      Streamers   Avg_viewers  Avg_channels  \
# count   14199.000000   14199.000000  14199.000000  14199.000000
# mean      576.888865   17119.430030   6485.749842    212.907881
# std      2631.148026   54465.625079  22670.546870    742.668106
# min         1.000000       0.000000    120.000000      0.000000
# 25%        51.000000    1461.000000    498.000000     16.000000
# 50%       121.000000    4088.000000   1110.000000     42.000000
# 75%       315.000000   10651.000000   3104.500000    120.000000
# max    129860.000000 1013029.000000 479209.000000  13789.000000
#
#        Avg_viewer_ratio
# count      14199.000000
# mean          82.298461
# std          371.322250
# min            1.980000
# 25%           16.100000
# 50%           29.150000
# 75%           57.820000
# max        13601.870000

# %%
a = df.groupby(["Year"]).sum()
a["Hours_watched"].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
b= df.groupby(["Month"]).mean()
plt=b["Hours_watched"].plot(color="black" ,linewidth=5)

# %%
b= df.groupby(["Month"]).mean()
b["Hours_watched"]
# Out:
# Month
# 1    4486574.377500
# 2    4138724.405338
# 3    4646377.398333
# 4    5111525.009167
# 5    5146534.950833
# 6    4770525.838333
# 7    4724070.046667
# 8    4879637.370833
# 9    4612933.686667
# 10   5037985.364167
# 11   4863930.811667
# 12   4272241.736000
# Name: Hours_watched, dtype: float64

# %%
b= df.groupby(["Month"]).sum()
b["Hours_watched"]
# Out:
# Month
# 1     5383889253
# 2     4962330562
# 3     5575652878
# 4     6133830011
# 5     6175841941
# 6     5724631006
# 7     5668884056
# 8     5855564845
# 9     5535520424
# 10    6045582437
# 11    5836716974
# 12    4272241736
# Name: Hours_watched, dtype: int64

# %%
5383889253/4486574.377500
# Out:
# 1200.0

# %%
df["Game"].count()
# Out:
# 14199

# %%
df["Game"].nunique()
# Out:
# 1784

# %%
df[(df.Game == "Just Chatting")]
# Out:
#        Rank           Game  Month  Year  Hours_watched Hours_Streamed  \
# 6430     31  Just Chatting      9  2018        3791420          37737
# 6603      4  Just Chatting     10  2018       37306055         443473
# 6802      3  Just Chatting     11  2018       45819619         533962
# 7002      3  Just Chatting     12  2018       54386753         684341
# 7202      3  Just Chatting      1  2019       59064487         803672
# 7403      4  Just Chatting      2  2019       51698098         733647
# 7604      5  Just Chatting      3  2019       58236586         878360
# 7803      4  Just Chatting      4  2019       58637850         862890
# 8003      4  Just Chatting      5  2019       60652701         894976
# 8202      3  Just Chatting      6  2019       61663846         908320
# 8404      5  Just Chatting      7  2019       60624575         939477
# 8604      5  Just Chatting      8  2019       65042052        1002669
# 8802      3  Just Chatting      9  2019       63835583         971238
# 9002      3  Just Chatting     10  2019       68419996        1089800
# 9201      2  Just Chatting     11  2019       68267215        1067460
# 9400      1  Just Chatting     12  2019       83590066        1265051
# 9601      2  Just Chatting      1  2020       88378302        1409820
# 9801      2  Just Chatting      2  2020       89799571        1379006
# 10001     2  Just Chatting      3  2020      112003986        1808562
# 10201     2  Just Chatting      4  2020      141922978        2303367
# 10400     1  Just Chatting      5  2020      181536582        2602630
# 10600     1  Just Chatting      6  2020      174681829        2438913
# 10800     1  Just Chatting      7  2020      182688702        2582898
# 11000     1  Just Chatting      8  2020      170478547        2607784
# 11200     1  Just Chatting      9  2020      168706952        2550812
# 11400     1  Just Chatting     10  2020      203159545        2757457
# 11600     1  Just Chatting     11  2020      233960587        2867763
# 11800     1  Just Chatting     12  2020      248573448        3149975
# 12000     1  Just Chatting      1  2021      248144653        3420670
# 12200     1  Just Chatting      2  2021      240445690        3202966
# 12400     1  Just Chatting      3  2021      270395369        3485083
# 12600     1  Just Chatting      4  2021      289547911        3544601
# 12800     1  Just Chatting      5  2021      285948196        3522387
# 13000     1  Just Chatting      6  2021      252985317        3188627
# 13200     1  Just Chatting      7  2021      240051080        3204980
# 13400     1  Just Chatting      8  2021      249610555        3255305
# 13600     1  Just Chatting      9  2021      222594651        2982598
# 13800     1  Just Chatting     10  2021      217994303        2945069
# 14000     1  Just Chatting     11  2021      231514981        2828547
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 6430         105145            613      13920         5273            52
# 6603         156436           1163      76354        50210           596
# 6802         227149           1213      91574        63726           742
# 7002         223139           1847     115690        73198           921
# 7202         184542           1757     134201        79494          1081
# 7403         182185           2336     121349        77046          1093
# 7604         211835           1781     135026        78380          1182
# 7803         219754           1848     135011        81554          1200
# 8003         194008           1834     139132        81632          1204
# 8202         234098           2724     145157        85763          1263
# 8404         175774           1771     146862        81594          1264
# 8604         203000           1967     155221        87539          1349
# 8802         245697           2777     148818        88783          1350
# 9002         244285           2347     157126        92086          1466
# 9201         287294           2373     161010        94947          1484
# 9400         267822           3315     189224       112503          1702
# 9601         631876           2959     214185       118947          1897
# 9801         309048           2849     195799       129208          1984
# 10001        360279           4180     248185       150745          2434
# 10201        548653           4912     272519       197389          3203
# 10400        839576           6961     314436       244329          3502
# 10600        777678          12126     310815       242951          3392
# 10800        573912           5586     324606       245879          3476
# 11000        508828           5233     328529       229446          3509
# 11200        650779           8045     332334       234641          3547
# 11400        684417           6778     355568       273431          3711
# 11600        986105           6855     376893       325397          3988
# 11800       1117874           8817     413135       334553          4239
# 12000       2787896           8240     464702       333976          4603
# 12200       1138978          13308     444507       358339          4773
# 12400       1086313           8309     469545       363923          4690
# 12600        937749           8026     474257       402709          4929
# 12800        983678           7465     462447       384856          4740
# 13000       1034076           8657     429682       351857          4434
# 13200        772137           6307     425721       323083          4313
# 13400        736910           6517     428053       335949          4381
# 13600        773047           8506     394043       309589          4148
# 13800        715797           6420     376011       293397          3963
# 14000        878286           6493     368108       321995          3934
#
#        Avg_viewer_ratio
# 6430         100.470000
# 6603          84.120000
# 6802          85.810000
# 7002          79.470000
# 7202          73.490000
# 7403          70.470000
# 7604          66.300000
# 7803          67.960000
# 8003          67.770000
# 8202          67.890000
# 8404          64.530000
# 8604          64.870000
# 8802          65.730000
# 9002          62.780000
# 9201          63.950000
# 9400          66.080000
# 9601          62.690000
# 9801          65.120000
# 10001         61.930000
# 10201         61.620000
# 10400         69.750000
# 10600         71.620000
# 10800         70.730000
# 11000         65.370000
# 11200         66.140000
# 11400         73.680000
# 11600         81.580000
# 11800         78.910000
# 12000         72.540000
# 12200         75.070000
# 12400         77.590000
# 12600         81.690000
# 12800         81.180000
# 13000         79.340000
# 13200         74.900000
# 13400         76.680000
# 13600         74.630000
# 13800         74.020000
# 14000         81.850000

# %%
dff=pd.DataFrame(df.groupby(["Game"]).mean())
dff["Hours_watched"]
# Out:
# Game
# .hack//G.U. Last Recode        145350.000000
# 60 Parsecs!                    529688.000000
# 60 Seconds!                    314900.555556
# 7 Days to Die                  846377.211268
# <U+014C>kami                   181539.000000
#                                    ...
# osu!                          1006780.183099
# rFactor 2                      645424.000000
# skribbl.io                     635118.714286
# some some convenience store    342876.000000
# theHunter: Call of the Wild    280219.444444
# Name: Hours_watched, Length: 1784, dtype: float64

# %%
df[(df.Game == "7 Days to Die")]
# Out:
#        Rank           Game  Month  Year  Hours_watched Hours_Streamed  \
# 128     129  7 Days to Die      1  2016         269681          12131
# 358     159  7 Days to Die      2  2016         139365           8921
# 591     192  7 Days to Die      3  2016          99191           8504
# 716     117  7 Days to Die      4  2016         212199          15614
# 915     116  7 Days to Die      5  2016         195722          11696
# ...     ...            ...    ...   ...            ...            ...
# 13337   138  7 Days to Die      7  2021        1249874         124013
# 13494    95  7 Days to Die      8  2021        2494751         130400
# 13743   144  7 Days to Die      9  2021        1071395         114887
# 13943   144  7 Days to Die     10  2021         971803          96589
# 14165   166  7 Days to Die     11  2021         884544         103636
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 128            4405             44       1240          362            16
# 358            3812             34        887          200            12
# 591            4817             58        932          133            11
# 716            3993             52       1439          295            21
# 915            4507             44       1245          263            15
# ...             ...            ...        ...          ...           ...
# 13337         28696            289       9748         1682           166
# 13494         26935            312      10174         3357           175
# 13743          9869            287       9019         1490           159
# 13943          9631            237       7697         1307           129
# 14165         12544            271       8079         1230           144
#
#        Avg_viewer_ratio
# 128           22.230000
# 358           15.620000
# 591           11.660000
# 716           13.590000
# 915           16.730000
# ...                 ...
# 13337         10.080000
# 13494         19.130000
# 13743          9.330000
# 13943         10.060000
# 14165          8.540000
#
# [71 rows x 12 columns]

# %%
train,test = train_test_split(df, test_size=0.25)

# %%
train.head()
# Out:
#       Rank                                     Game  Month  Year  \
# 8922   123  The Legend of Zelda: Breath of the Wild      9  2019
# 9614    15                             Apex Legends      1  2020
# 9875    76                     Farming Simulator 19      2  2020
# 7287    88                              PUBG Mobile      1  2019
# 6716   117                  Total War: Warhammer II     10  2018
#
#       Hours_watched Hours_Streamed  Peak_viewers  Peak_channels  Streamers  \
# 8922         478589          26448         63594             78       2897
# 9614       13757762        1270815         41996           3193     132964
# 9875        1116890         104669         16503            557      13227
# 7287        1007630         148577          7754            380      19066
# 6716         584621          13840         11790             39       1397
#
#       Avg_viewers  Avg_channels  Avg_viewer_ratio
# 8922          665            36         18.100000
# 9614        18516          1710         10.830000
# 9875         1607           150         10.670000
# 7287         1356           199          6.780000
# 6716          786            18         42.240000

# %%
train.shape
# Out:
# (10649, 12)

# %%
test.head()
# Out:
#        Rank                 Game  Month  Year  Hours_watched Hours_Streamed  \
# 5553    154         Blade & Soul      4  2018         305928          31507
# 4167    168       Chrono Trigger      9  2017         199002           1988
# 6408      9            Overwatch      9  2018       20588095         903065
# 8329    130               Metin2      6  2019         522545          17456
# 12505   106  Super Mario Maker 2      3  2021        1898505          39214
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 5553           2753             87       2653          425            43
# 4167          27319             10        259          276             2
# 6408         123275           2959     122273        28634          1256
# 8329          24558             88       1485          726            24
# 12505         27765            142       3629         2555            52
#
#        Avg_viewer_ratio
# 5553           9.710000
# 4167         100.100000
# 6408          22.800000
# 8329          29.930000
# 12505         48.410000

# %%
test.shape
# Out:
# (3550, 12)

# %%
reg=linear_model.LinearRegression(normalize=True)
reg.fit(train[["Streamers"]],train[["Hours_watched"]])
# Out:
# LinearRegression(normalize=True)

# %%
reg.predict(test[["Streamers"]])
# Out:
# array([[ 1435598.69231543],
#        [  894469.24413187],
#        [28473988.24608218],
#        ...,
#        [39905743.40142202],
#        [ 2275321.29047831],
#        [ 2117322.34132196]])

# %%
plt.scatter(x=train[["Hours_watched"]], y=test[["Hours_watched"]], c="purple", alpha=0.4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-0f8f314405b5> in <module>
# ----> 1 plt.scatter(x=train[["Hours_watched"]], y=test[["Hours_watched"]], c="purple", alpha=0.4)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4439         y = np.ma.ravel(y)
#    4440         if x.size != y.size:
# -> 4441             raise ValueError("x and y must be the same size")
#    4442
#    4443         if s is None:
#
# ValueError: x and y must be the same size

# %%
df.corr()
# Out:
#                       Rank     Month      Year  Hours_watched  Peak_viewers  \
# Rank              1.000000  0.000097 -0.000024      -0.390575     -0.349157
# Month             0.000097  1.000000 -0.033942       0.003300      0.001239
# Year             -0.000024 -0.033942  1.000000       0.145643      0.153407
# Hours_watched    -0.390575  0.003300  0.145643       1.000000      0.714579
# Peak_viewers     -0.349157  0.001239  0.153407       0.714579      1.000000
# Peak_channels    -0.262927  0.014806  0.124118       0.525957      0.532727
# Streamers        -0.366517 -0.002439  0.137188       0.752494      0.568395
# Avg_viewers      -0.390540  0.001591  0.145824       0.999618      0.713820
# Avg_channels     -0.356438 -0.000169  0.162934       0.759460      0.564185
# Avg_viewer_ratio  0.069142 -0.037627 -0.062422      -0.017882      0.058868
#
#                   Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# Rank                  -0.262927  -0.366517    -0.390540     -0.356438
# Month                  0.014806  -0.002439     0.001591     -0.000169
# Year                   0.124118   0.137188     0.145824      0.162934
# Hours_watched          0.525957   0.752494     0.999618      0.759460
# Peak_viewers           0.532727   0.568395     0.713820      0.564185
# Peak_channels          1.000000   0.746240     0.526377      0.784443
# Streamers              0.746240   1.000000     0.752319      0.961246
# Avg_viewers            0.526377   0.752319     1.000000      0.759666
# Avg_channels           0.784443   0.961246     0.759666      1.000000
# Avg_viewer_ratio      -0.028872  -0.043858    -0.017910     -0.040135
#
#                   Avg_viewer_ratio
# Rank                      0.069142
# Month                    -0.037627
# Year                     -0.062422
# Hours_watched            -0.017882
# Peak_viewers              0.058868
# Peak_channels            -0.028872
# Streamers                -0.043858
# Avg_viewers              -0.017910
# Avg_channels             -0.040135
# Avg_viewer_ratio          1.000000

# %%
y = df.iloc[:,8:9]
y
# Out:
#        Streamers
# 0         129172
# 1         120849
# 2          44074
# 3          36170
# 4         214054
# ...          ...
# 14195       6374
# 14196       1273
# 14197       6686
# 14198       1716
# 14199       1152
#
# [14199 rows x 1 columns]

# %%
X = df.iloc[:,4:5]
X
# Out:
#        Hours_watched
# 0           94377226
# 1           47832863
# 2           45185893
# 3           39936159
# 4           16153057
# ...              ...
# 14195         645300
# 14196         645248
# 14197         635375
# 14198         617396
# 14199         607581
#
# [14199 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model

y = df.iloc[:,8:9]
X = df.iloc[:,4:5]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
plt.scatter(x=y_train, y=y_pred_train, c="black", alpha=0.4)

a = np.polyfit(y_train, y_pred_train, 1)
p = np.poly1d(a)
plt.plot(y_test,p(y_test),"red")
plt.xlabel('Correct Value')
plt.ylabel('Prediction')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-314b96ff5683> in <module>
#      11 plt.scatter(x=y_train, y=y_pred_train, c="black", alpha=0.4)
#      12
# ---> 13 a = np.polyfit(y_train, y_pred_train, 1)
#      14 p = np.poly1d(a)
#      15 plt.plot(y_test,p(y_test),"red")
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     626         raise ValueError("expected deg >= 0")
#     627     if x.ndim != 1:
# --> 628         raise TypeError("expected 1D vector for x")
#     629     if x.size == 0:
#     630         raise TypeError("expected non-empty vector for x")
#
# TypeError: expected 1D vector for x

# %%
X=df[["Hours_watched"]]

X.head()
# Out:
#    Hours_watched
# 0       94377226
# 1       47832863
# 2       45185893
# 3       39936159
# 4       16153057

# %%
y=df["Streamers"]
y
# Out:
# 0        129172
# 1        120849
# 2         44074
# 3         36170
# 4        214054
#           ...
# 14195      6374
# 14196      1273
# 14197      6686
# 14198      1716
# 14199      1152
# Name: Streamers, Length: 14199, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train.shape
# Out:
# (11359, 1)

# %%
y_train.shape
# Out:
# (11359,)

# %%
linreg=LinearRegression().fit(X_train,y_train)
linreg.coef_
# Out:
# array([0.00259158])

# %%
linreg.intercept_
# Out:
# 5084.469413547193

# %%
linreg.coef_
# Out:
# array([0.00259158])

# %%
linreg.score(X_train,y_train)
# Out:
# 0.5749985188148989

# %%
linreg.score(X_test,y_test)
# Out:
# 0.5210192722324178

# %%
#Overfitting yok ama underfitting var ? https://youtu.be/gFzq_oz_mSQ

# %%
X=df
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#        Rank                       Game  Month  Year  Hours_watched  \
# 10541   142  Call of Duty: Black Ops 4      5  2020         937302
# 10801     2          League of Legends      7  2020      135123272
# 13534   135       Call of Duty: Mobile      8  2021        1277121
# 937     138               Mario Kart 8      5  2016         155186
# 2195    196                  RPG Maker     11  2016         110345
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 10541         200433         10165            453      16929         1261
# 10801        3248650        494759           7246     223201       181861
# 13534         194883         56900            550      17250         1718
# 937             4675          6258             28       1064          208
# 2195            1131          7584              9        168          153
#
#        Avg_channels  Avg_viewer_ratio
# 10541           269          4.680000
# 10801          4372         41.590000
# 13534           262          6.550000
# 937               6         33.190000
# 2195              1         97.560000

# %%
X_train.dtypes
# Out:
# Rank                  int64
# Game                 object
# Month                 int64
# Year                  int64
# Hours_watched         int64
# Hours_Streamed       object
# Peak_viewers          int64
# Peak_channels         int64
# Streamers             int64
# Avg_viewers           int64
# Avg_channels          int64
# Avg_viewer_ratio    float64
# dtype: object

# %%
Y= df.iloc[:,8:9].values.reshape(-1,1)#Streamers
X = df.iloc[:,4:5].values.reshape(-1,1)#Hours_watched

# %%
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
fig = plt.figure(figsize=(17,10))

plt.scatter(X, Y, color="turquoise")
plt.plot(X, Y_pred, color='darkslategray')
plt.title('Correct vs Predict')
plt.xlabel('Correct')
plt.ylabel('Predict')
plt.show()
